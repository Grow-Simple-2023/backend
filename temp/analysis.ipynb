# %%
import json


with open("final.json", "r") as f:
    final = json.load(f)

with open("initial_info.json", "r") as f:
    initial_info = json.load(f)
    
with open("complete_info.json", "r") as f:
    complete_info = json.load(f)

# %%
with open("final.json", "r") as f:
    final = json.load(f)

# %%
complete_info = complete_info['unassigned_items']

# %%
def item_no_to_lat_long(item_no):
    if item_no == -1: return (30, 100)
    else: return (complete_info[item_no]['location']['latitude'], complete_info[item_no]['location']['longitude'])

# %%
l = []
for x in complete_info:
    l.append(x['id'])
print(l)
# Out:
# ['object0', 'object4', 'object5', 'object9', 'object17', 'object38', 'object49', 'object52', 'object67', 'object68', 'object89', 'object97', 'object104', 'object110', 'object111', 'object113', 'object139', 'object146', 'object148', 'object164', 'object170', 'object172', 'object178', 'object181', 'object190', 'object201', 'object208', 'object212', 'object226', 'object227', 'object230', 'object233', 'object234', 'object235', 'object240', 'object241', 'object244', 'object252', 'object265', 'object291', 'object295', 'object301', 'object306', 'object318', 'object322', 'object364', 'object368', 'object373', 'object386', 'object414', 'object419', 'object424', 'object441', 'object478', 'object485', 'object489', 'object499', 'object510', 'object520', 'object524', 'object525', 'object539', 'object557', 'object566', 'object570', 'object578', 'object598', 'object620', 'object627', 'object630', 'object632', 'object639', 'object645', 'object656', 'object670', 'object674', 'object675', 'object681', 'object691', 'object696', 'object717', 'object718', 'object731', 'object739', 'object747', 'object763', 'object776', 'object777', 'object797', 'object802', 'object804', 'object811', 'object817', 'object819', 'object829', 'object831', 'object843', 'object855', 'object859', 'object869', 'object872', 'object878', 'object885', 'object886', 'object900', 'object904', 'object907', 'object916', 'object921', 'object922', 'object928', 'object936', 'object944', 'object953', 'object969', 'object974', 'object984', 'object985', 'object992']

# %%
import matplotlib.pyplot as plt

for route in final['routes']:
    route.append(route[0])

for route in final['routes']:
    plt.plot([item_no_to_lat_long(item_no)[0] for item_no in route], [item_no_to_lat_long(item_no)[1] for item_no in route], 'o-')
